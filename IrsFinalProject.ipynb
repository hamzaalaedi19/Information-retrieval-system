# %% [markdown]
# Version #1

# %%
import requests
import re
from collections import defaultdict
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.stem import PorterStemmer

nltk.download('wordnet')
nltk.download('stopwords')

class Crawler:
    def __init__(self):
        self.to_visit = []
        self.visited = set()
        self.inverted_index = defaultdict(list)
        self.stop_words = set(stopwords.words('english'))
        self.stemmer = PorterStemmer()

    def fetch(self, url):
        print(f'Now fetching: {url}')
        try:
            res = requests.get(url).content
            return res
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return b''

    def get_current_url(self):
        if not self.to_visit:
            return None
        res = self.to_visit.pop(0)
        while res in self.visited:
            if not self.to_visit:
                return None
            res = self.to_visit.pop(0)
        return res

    def get_links(self, content):
        urls = re.findall(r'<a href="([^"]+)"', str(content))
        for url in urls:
            if re.match(r'^http', url) and url not in self.visited and url not in self.to_visit:
                self.to_visit.append(url)

    def get_paragraphs(self, content):
        return re.findall(r'<p>(.*?)</p>', str(content), re.DOTALL)

    def preprocess_text(self, text):

        text = re.sub(r'[^\w\s]', '', text.lower())

        words = [word for word in text.split() if word not in self.stop_words]

        stemmed_words = [self.stemmer.stem(word) for word in words]
        return stemmed_words

    def update_inverted_index(self, content, url):
        words = self.preprocess_text(content.decode('utf-8'))
        for word in set(words):
            self.inverted_index[word].append(url)

    def search_word_in_index(self, word):
        word = self.stemmer.stem(word.lower())
        found_urls = self.inverted_index.get(word, [])
        print(f'Word "{word}" found in: {found_urls}')
        return found_urls

    def search_words_and_in_index(self, word1, word2):
        urls_word1 = set(self.search_word_in_index(word1))
        urls_word2 = set(self.search_word_in_index(word2))
        common_urls = urls_word1.intersection(urls_word2)
        print(f'Words "{word1}" and "{word2}" found together in: {list(common_urls)}')
        return list(common_urls)

    def search_words_or_in_index(self, word1, word2):
        urls_word1 = set(self.search_word_in_index(word1))
        urls_word2 = set(self.search_word_in_index(word2))
        all_urls = urls_word1.union(urls_word2)
        print(f'Word "{word1}" or "{word2}" found in: {list(all_urls)}')
        return list(all_urls)

    def search_phrase_exclude_word_in_index(self, phrase, exclude_word):
        urls_with_phrase = set(self.search_word_in_index(phrase))
        urls_with_exclude_word = set(self.search_word_in_index(exclude_word))
        final_urls = urls_with_phrase.difference(urls_with_exclude_word)
        print(f'Phrase "{phrase}" found without "{exclude_word}" in: {list(final_urls)}')
        return list(final_urls)

    def crawl(self, url, depth=15):
        self.to_visit.append(url)
        while len(self.visited) < depth and self.to_visit:
            current_url = self.get_current_url()
            if current_url is None:
                break

            content = self.fetch(current_url)
            self.visited.add(current_url)
            self.get_links(content)

            paragraphs = self.get_paragraphs(content)
            for paragraph in paragraphs:
                self.update_inverted_index(paragraph.encode('utf-8'), current_url)

        print('Visited URLs:', len(self.visited))


crawler = Crawler()
root_url = 'https://www.python.org'

print(f'\n--- Starting crawl for site: {root_url} ---')
crawler.crawl(root_url, depth=15)
print(f'--- Finished processing site: {root_url} ---')


print("\n--- Search Examples ---")
crawler.search_word_in_index("Python")
crawler.search_words_and_in_index("Python", "programming")
crawler.search_words_or_in_index("Python", "Java")
crawler.search_phrase_exclude_word_in_index("programming", "Java")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# --- Starting crawl for site: https://www.python.org ---
# Now fetching: https://www.python.org
# Now fetching: http://browsehappy.com/
# Now fetching: https://www.python.org/psf/
# Now fetching: https://docs.python.org
# Now fetching: https://pypi.org/
# Now fetching: https://psfmember.org/civicrm/contribute/transact?reset=1&id=2
# Now fetching: https://www.linkedin.com/company/python-software-foundation/
# Now fetching: https://fosstodon.org/@ThePSF
# Now fetching: https://twitter.com/ThePSF
# Now fetching: http://brochure.getpython.info/
# Now fetching: https://docs.python.org/3/license.html
# Now fetching: https://wiki.python.org/moin/BeginnersGuide
# Now fetching: https://devguide.python.org/
# Now fetching: https://docs.python.org/faq/
# Now fetching: http://wiki.python.org/moin/Languages
# Visited URLs: 15
# --- Finished processing site: https://www.python.org ---
#
# --- Search Examples ---
# Word "python" found in: ['https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://docs.python.org', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'http://brochure.getpython.info/', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/']
# Word "python" found in: ['https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://docs.python.org', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'http://brochure.getpython.info/', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/']
# Word "program" found in: ['https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org/psf/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2']
# Words "Python" and "programming" found together in: ['https://www.python.org/psf/', 'https://www.python.org', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2']
# Word "python" found in: ['https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://www.python.org/psf/', 'https://docs.python.org', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://pypi.org/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'http://brochure.getpython.info/', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://docs.python.org/3/license.html', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/', 'https://devguide.python.org/']
# Word "java" found in: []
# Word "Python" or "Java" found in: ['https://www.python.org/psf/', 'https://docs.python.org', 'https://www.python.org', 'https://docs.python.org/3/license.html', 'https://devguide.python.org/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'http://brochure.getpython.info/', 'https://pypi.org/']
# Word "program" found in: ['https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org', 'https://www.python.org/psf/', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2']
# Word "java" found in: []
# Phrase "programming" found without "Java" in: ['https://www.python.org/psf/', 'https://www.python.org', 'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2']
# ['https://www.python.org/psf/',
#  'https://www.python.org',
#  'https://psfmember.org/civicrm/contribute/transact?reset=1&id=2']

# %% [markdown]
# Version #2

# %% [markdown]
# تم تطوير عمليات إدخال

# %% [markdown]
#  عمل  لعرض النتائج وعمليات البحث البدائية demo function

# %%
import requests
import re
from collections import defaultdict
import time
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

class AdvancedCrawler:
    def __init__(self):
        self.to_visit = []
        self.visited = set()
        self.inverted_index = defaultdict(list)
        self.stop_words = set(stopwords.words('english'))
        self.stemmer = PorterStemmer()

    def fetch(self, url):
        """Fetch content from a URL."""
        try:
            res = requests.get(url, timeout=10)
            if res.status_code == 200:
                return res.content
        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
        return b''

    def parse_links(self, content, base_url):
        """Extract and normalize links from HTML content."""
        links = re.findall(r'<a href="([^"]+)"', str(content))
        for link in links:
            if link.startswith('/'):
                link = base_url + link
            if link.startswith('http') and link not in self.visited:
                self.to_visit.append(link)

    def tokenize_and_preprocess(self, text):
        """Tokenize and preprocess text."""
        tokens = word_tokenize(text.lower())
        tokens = [self.stemmer.stem(word) for word in tokens if word.isalnum() and word not in self.stop_words]
        return tokens

    def update_inverted_index(self, content, url):
        """Update the inverted index with preprocessed tokens."""
        text = content.decode('utf-8', errors='ignore')
        tokens = self.tokenize_and_preprocess(text)
        for token in set(tokens):
            self.inverted_index[token].append(url)

    def search_word_in_index(self, word):
        """Search for a single word in the inverted index."""
        word = self.stemmer.stem(word.lower())
        return self.inverted_index.get(word, [])

    def search_phrase_exclude_word_in_index(self, phrase, exclude_word):
        """Search for a phrase excluding a specific word."""
        phrase_urls = set(self.search_word_in_index(phrase))
        exclude_urls = set(self.search_word_in_index(exclude_word))
        return list(phrase_urls - exclude_urls)

    def crawl(self, root_url, depth):
        """Perform crawling starting from a root URL up to a specific depth."""
        self.to_visit.append(root_url)
        while len(self.visited) < depth and self.to_visit:
            current_url = self.to_visit.pop(0)
            if current_url in self.visited:
                continue

            content = self.fetch(current_url)
            if content:
                self.visited.add(current_url)
                self.parse_links(content, root_url)
                self.update_inverted_index(content, current_url)

            time.sleep(1)  # Politeness delay

    def run_demo(self):
        """Run a search demo."""
        query = input("Enter search query: ")
        exclude = input("Enter word to exclude (optional): ").strip()
        if exclude:
            results = self.search_phrase_exclude_word_in_index(query, exclude)
        else:
            results = self.search_word_in_index(query)

        if results:
            print(f"Found results in the following URLs: {results}")
        else:
            print("No results found.")

if __name__ == "__main__":
    root_url = input("Enter the root URL to start crawling: ")
    depth = int(input("Enter the crawl depth: "))
    crawler = AdvancedCrawler()
    crawler.crawl(root_url, depth)
    print(f"Crawl complete. Indexed {len(crawler.visited)} pages.")
    crawler.run_demo()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Enter the root URL to start crawling: https://www.bemyeyes.com/
# Enter the crawl depth: 15
# Crawl complete. Indexed 15 pages.
# Enter search query: solutions
# Enter word to exclude (optional):
# Found results in the following URLs: ['https://www.bemyeyes.com/', 'https://www.bemyeyes.com/blog/be-my-eyes-meta-accessibility-partnership', 'https://www.bemyeyes.com//', 'https://www.bemyeyes.com//solutions', 'https://www.bemyeyes.com//accessible-customer-service', 'https://www.bemyeyes.com//customers', 'https://www.bemyeyes.com//corporate-volunteering', 'https://www.bemyeyes.com//be-my-eyes-for-work', 'https://www.bemyeyes.com//products', 'https://www.bemyeyes.com//mobile-app', 'https://www.bemyeyes.com//be-my-eyes-for-windows', 'https://www.bemyeyes.com//ray-ban-meta', 'https://www.bemyeyes.com//accessible-service-suite', 'https://www.bemyeyes.com//service-directory', 'https://www.bemyeyes.com//service-ai']

# %% [markdown]
# Version #3

# %% [markdown]
# Final Version

# %% [markdown]
# تم تطوير عمليات البحث بشكل كامل

# %% [markdown]
# تم إضافة and ,or

# %% [markdown]
# تم إضافة methods

# %% [markdown]
# 1- display reults لعرض النتائج عمودياً

# %% [markdown]
# 2-save results

# %%
#mid project final version
import requests
import re
from collections import defaultdict
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

class Crawler:
    def __init__(self):
        self.to_visit = []
        self.visited = set()
        self.inverted_index = defaultdict(list)
        self.stop_words = set(stopwords.words('english'))
        self.stemmer = PorterStemmer()

# Fetch content from a URL
    def fetch(self, url):

        try:
            res = requests.get(url)
            if res.status_code == 200:
                return res.content
        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
        return b''

    def get_links(self, content, base_url):
        links = re.findall(r'<a href="([^"]+)"', str(content))
        for link in links:
            if link.startswith('/'):
                link = base_url + link
            if link.startswith('http') and link not in self.visited:
                self.to_visit.append(link)

    def tokenize_and_preprocess(self, text):
        tokens = word_tokenize(text.lower())
        tokens = [self.stemmer.stem(word) for word in tokens if word.isalnum() and word not in self.stop_words]
        return tokens


    def update_inverted_index(self, content, url):

        text = content.decode('utf-8', errors='ignore')
        tokens = self.tokenize_and_preprocess(text)
        for token in set(tokens):
            self.inverted_index[token].append(url)


    def search_word_in_index(self, word):

        word = self.stemmer.stem(word.lower())
        return self.inverted_index.get(word, [])

    def search_words_and_in_index(self, word1, word2):

        urls_word1 = set(self.search_word_in_index(word1))
        urls_word2 = set(self.search_word_in_index(word2))
        common_urls = urls_word1.intersection(urls_word2)
        return list(common_urls)

    def search_words_or_in_index(self, word1, word2):

        urls_word1 = set(self.search_word_in_index(word1))
        urls_word2 = set(self.search_word_in_index(word2))
        all_urls = urls_word1.union(urls_word2)
        return list(all_urls)

    def search_phrase_exclude_word_in_index(self, phrase, exclude_word):

        phrase_urls = set(self.search_word_in_index(phrase))
        exclude_urls = set(self.search_word_in_index(exclude_word))
        return list(phrase_urls - exclude_urls)

    def display_results(self, results):

        if results:
            print("\n--- Results ---")
            for idx, url in enumerate(results, 1):
                print(f"{idx}. {url}")
        else:
            print("\n No results found.")

    def save_results(self, results):
        filepath = input("Enter the file name to save the results (e.g., results.txt): ")
        with open(filepath, 'w') as file:
            for url in results:
                file.write(url + '\n')
        print(f"Results have been saved in {filepath}")


    def crawl(self, root_url, depth):
        self.to_visit.append(root_url)
        while len(self.visited) < depth and self.to_visit:
            current_url = self.to_visit.pop(0)

            content = self.fetch(current_url)
            if content:
                self.visited.add(current_url)
                self.get_links(content, root_url)
                self.update_inverted_index(content, current_url)


    def run_demo(self):
        print("\n--- Search Options ---")
        print("1. Search for a single word.")
        print("2. Search for two words with AND condition.")
        print("3. Search for two words with OR condition.")
        print("4. Search for a phrase excluding a specific word.")

        choice = int(input("Enter the search option (1/2/3/4): "))
        if choice == 1:
            word = input("Enter the word to search: ")
            results = self.search_word_in_index(word)
        elif choice == 2:
            word1 = input("Enter the first word: ")
            word2 = input("Enter the second word: ")
            results = self.search_words_and_in_index(word1, word2)
        elif choice == 3:
            word1 = input("Enter the first word: ")
            word2 = input("Enter the second word: ")
            results = self.search_words_or_in_index(word1, word2)
        elif choice == 4:
            phrase = input("Enter the phrase: ")
            exclude_word = input("Enter the word to exclude: ")
            results = self.search_phrase_exclude_word_in_index(phrase, exclude_word)
        else:
            print("Invalid choice.")
            return

        if results:
            print(f"Found results in the following URLs: {results}")
        else:
            print("No results found.")

        self.display_results(results)

        if results:
            save = input("Do you want to save reults (y/n): ").lower()
            if save == 'y':
                self.save_results(results)

if __name__ == "__main__":
    root_url = input("Enter the root URL to start crawling: ")
    depth = int(input("Enter the crawl depth: "))
    crawler = Crawler()
    crawler.crawl(root_url, depth)
    print(f"Crawl complete. Indexed {len(crawler.visited)} pages.")
    crawler.run_demo()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Enter the root URL to start crawling: https://www.wikipedia.org/
# Enter the crawl depth: 5
# Crawl complete. Indexed 5 pages.
#
# --- Search Options ---
# 1. Search for a single word.
# 2. Search for two words with AND condition.
# 3. Search for two words with OR condition.
# 4. Search for a phrase excluding a specific word.
# Enter the search option (1/2/3/4): 1
# Enter the word to search: search
# Found results in the following URLs: ['https://www.wikipedia.org/', 'https://www.wikipedia.org///zh.wikipedia.org/', 'https://www.wikipedia.org///zh-min-nan.wikipedia.org/', 'https://www.wikipedia.org///sr.wikipedia.org/', 'https://www.wikipedia.org///zh-yue.wikipedia.org/']
#
# --- Results ---
# 1. https://www.wikipedia.org/
# 2. https://www.wikipedia.org///zh.wikipedia.org/
# 3. https://www.wikipedia.org///zh-min-nan.wikipedia.org/
# 4. https://www.wikipedia.org///sr.wikipedia.org/
# 5. https://www.wikipedia.org///zh-yue.wikipedia.org/
# Do you want to save reults (y/n): n

# %%
  # !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)

# %% [markdown]
# Final project IRS

# %%
import requests
import re
from collections import defaultdict
import math
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import download

# Download necessary NLTK data
download('punkt')
nltk.download ('punkt_tab')
download('stopwords')

class SearchEngine:
    def __init__(self):
        self.to_visit = []
        self.visited = set()
        self.inverted_index = defaultdict(list)
        self.tfidf_index = defaultdict(lambda: defaultdict(float))
        self.positional_index = defaultdict(lambda: defaultdict(list))
        self.stop_words = set(stopwords.words('english'))
        self.stemmer = PorterStemmer()
        self.document_lengths = {}

    def fetch(self, url):
        try:
            res = requests.get(url)
            if res.status_code == 200:
                return res.content
        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
        return b''

    def get_links(self, content, base_url):
        links = re.findall(r'<a href="([^"]+)"', str(content))
        for link in links:
            if link.startswith('/'):
                link = base_url + link
            if link.startswith('http') and link not in self.visited:
                self.to_visit.append(link)

    def tokenize_and_preprocess(self, text):
        tokens = word_tokenize(text.lower())
        return [
            self.stemmer.stem(word)
            for word in tokens if word.isalnum() and word not in self.stop_words
        ]

    def update_indexes(self, content, url):
        text = content.decode('utf-8', errors='ignore')
        tokens = self.tokenize_and_preprocess(text)
        self.document_lengths[url] = len(tokens)

        # Positional Index
        for position, token in enumerate(tokens):
            self.positional_index[token][url].append(position)

        # Inverted Index
        for token in set(tokens):
            self.inverted_index[token].append(url)

        # TF-IDF Index
        token_counts = defaultdict(int)
        for token in tokens:
            token_counts[token] += 1
        for token, count in token_counts.items():
            tf = count / len(tokens)
            self.tfidf_index[token][url] = tf

    def compute_idf(self):
        total_docs = len(self.visited)
        for token, doc_dict in self.tfidf_index.items():
            idf = math.log(total_docs / len(doc_dict))
            for url in doc_dict:
                self.tfidf_index[token][url] *= idf

    def search_word_tfidf(self, word):
        word = self.stemmer.stem(word.lower())
        return sorted(
            self.tfidf_index.get(word, {}).items(),
            key=lambda x: x[1],
            reverse=True
        )

    def search_phrase(self, phrase):
        tokens = self.tokenize_and_preprocess(phrase)
        if not tokens:
            return []

        result_urls = set(self.positional_index[tokens[0]])
        for token in tokens[1:]:
            result_urls.intersection_update(self.positional_index[token])

        phrase_results = []
        for url in result_urls:
            positions = [
                self.positional_index[token][url] for token in tokens
            ]
            for start_pos in positions[0]:
                if all((start_pos + i) in positions[i] for i in range(1, len(tokens))):
                    phrase_results.append(url)
                    break
        return phrase_results

    def display_positional_index(self):
        print("\n--- Positional Inverted Index ---")
        for term, doc_positions in self.positional_index.items():
            print(f"Term: {term}")
            for doc, positions in doc_positions.items():
                print(f"  Document: {doc}, Positions: {positions}")

    def crawl(self, root_url, depth):
        self.to_visit.append(root_url)
        while len(self.visited) < depth and self.to_visit:
            current_url = self.to_visit.pop(0)
            if current_url in self.visited:
                continue
            content = self.fetch(current_url)
            if content:
                self.visited.add(current_url)
                self.get_links(content, root_url)
                self.update_indexes(content, current_url)
        self.compute_idf()

    def run_demo(self):
        print("\n--- Search Options ---")
        print("1. Search for a single word (TF-IDF based).")
        print("2. Search for a phrase (using Positional Inverted Index).")
        choice = int(input("Enter your choice (1/2): "))
        if choice == 1:
            word = input("Enter the word to search: ")
            results = self.search_word_tfidf(word)
            if results:
                print("\n--- TF-IDF Search Results ---")
                for idx, (url, score) in enumerate(results, 1):
                    print(f"{idx}. {url} (TF-IDF Score: {score:.4f})")
            else:
                print("\nNo results found for the word.")
        elif choice == 2:
            phrase = input("Enter the phrase to search: ")
            results = self.search_phrase(phrase)
            if results:
                print("\n--- Phrase Search Results (Positional Index) ---")
                for idx, url in enumerate(results, 1):
                    print(f"{idx}. {url}")
            else:
                print("\nNo results found for the phrase.")
        else:
            print("Invalid choice.")


if __name__ == "__main__":
    root_url = input("Enter the root URL to start crawling: ")
    depth = int(input("Enter the crawl depth: "))
    engine = SearchEngine()
    engine.crawl(root_url, depth)
    print(f"\nCrawl complete. Indexed {len(engine.visited)} pages.")

    # Display Positional Index
    engine.display_positional_index()

    # Run the demo
    engine.run_demo()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Streaming output truncated to the last 5000 lines.
# Term: catalog
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5392, 10736]
# Term: maintain
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5393, 6104, 6302, 9023]
# Term: oscar
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5395, 5397, 10721, 10723]
# Term: nierstrasz
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5396, 5398, 10722, 10724]
# Term: geneva
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5400, 5402]
# Term: wrote
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5403]
# Term: perl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5405, 5406, 5449, 5450, 8288]
# Term: period
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5408, 9206]
# Term: mirror
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5409, 15238, 15241]
# Term: rewrot
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5411]
# Term: format
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5413, 5497]
# Term: basi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5415, 6516]
# Term: primit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5420]
# Term: releas
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5423, 8760]
# Term: 18
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5430, 11114, 11156, 12875]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1926]
# Term: matthew
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5436, 8553, 8591]
# Term: gray
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5437, 8554, 8592]
# Term: massachusett
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5438]
# Term: institut
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5439, 12079]
# Term: mit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5441, 14575]
# Term: produc
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5442, 9300]
# Term: probabl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5443, 8499, 8515]
# Term: wandex
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5463, 8586]
# Term: purpos
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5464, 8501]
# Term: measur
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5466, 5788, 15150, 15154]
# Term: late
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5471, 5959]
# Term: second
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5473, 7207, 15791, 15795, 15823]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3865, 3869]
# Term: instead
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5486, 5733, 5863, 6199, 6433, 6546, 8653, 8916]
# Term: depend
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5487, 6377, 6831, 9309]
# Term: notifi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5488]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2137]
# Term: webmast
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5489, 7933, 8654, 8764]
# Term: administr
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5491, 8314, 9215]
# Term: particular
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5496, 6845]
# Term: 19
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5508, 9751, 9802, 11240, 11394, 12118]
# Term: jonathon
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5511, 5513]
# Term: fletcher
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5512, 5514]
# Term: build
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5523, 9406, 9411]
# Term: combin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5540, 6164, 7394, 8415, 9034]
# Term: three
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5541, 7272, 7291, 7319, 9004, 9149]
# Term: essenti
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5542]
# Term: featur
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5543, 5855, 6794, 8901]
# Term: crawl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5547, 6318, 6320, 6347, 6362, 6364, 6403, 6412, 6419, 6435, 6438, 6443, 6446, 6510, 7986, 15227, 15230]
# Term: resourc
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5552, 8100, 8112, 8120, 8128, 8154, 8167, 10738, 14755]
# Term: ran
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5555, 8602]
# Term: henc
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5557]
# Term: found
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5562, 5637, 5840, 6462, 7138, 7728, 8444, 9036]
# Term: encount
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5568, 7741]
# Term: text
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5572, 6253, 6796, 6799, 6918, 7037, 7140, 9475, 9736, 9787, 9842, 9850, 9901, 9942, 9957, 10014, 10086, 10106, 10164, 10175, 10183, 10222, 10227, 10243, 10288, 10344, 10389, 10444, 10456, 10498, 10547, 10604, 10612, 10662, 10730, 10784, 10797, 10843, 10897, 10960, 10970, 11009, 11046, 11058, 11068, 11105, 11161, 11218, 11229, 11274, 11287, 11333, 11381, 11405, 11416, 11466, 11473, 11518, 11582, 11591, 11676, 11714, 11766, 11811, 11865, 11911, 11967, 12018, 12072, 12123, 12183, 12219, 12277, 12285, 12296, 12350, 12379, 12434, 12442, 12452, 12524, 12613, 12623, 12639, 12691, 12723, 12747, 12794, 12819, 12867, 12889, 12898, 12907, 12971, 12990, 13001, 13011, 13020, 13083, 13105, 13114, 13123, 13185, 13213, 13222, 13277, 13286, 13328, 13335, 13378, 13398, 13452, 13514, 13583, 13670, 13721, 13799, 13809, 13850, 13875, 13913, 14001, 14026, 14038, 14101, 14123, 14136, 14146, 14156, 14209, 14345, 14355, 14429, 14508, 14518, 14567, 14580, 14630, 15176, 15178, 15741, 15754, 15771, 16167, 16170, 16205]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1410, 2029, 2113, 2166, 2175, 2184, 2425, 3039, 3245]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3965, 3979]
# Term: came
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5577, 7829, 7835]
# Term: unlik
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5578]
# Term: word
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5583, 6459, 6482, 6484, 6566, 6786, 6824, 6846, 8400, 8434, 8745, 9033, 9035]
# Term: becom
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5588, 7440, 9355, 9395, 9402]
# Term: major
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5590, 5613, 5868, 7499, 7949, 13801]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1440, 2446]
# Term: start
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5604, 8577, 8736]
# Term: carnegi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5605, 5608, 8966]
# Term: mellon
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5606, 5609, 8967]
# Term: launch
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5611, 5842, 6160, 6171, 6224, 8790]
# Term: commerci
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5614, 6932, 7434, 7528, 8787, 9259]
# Term: endeavor
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5615]
# Term: popular
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5618, 5681, 5704, 6124, 6851, 7222, 7254, 7280, 7395, 7442, 7489, 8863]
# Term: product
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5634, 12023]
# Term: jerri
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5638, 5640, 8854, 8857]
# Term: yang
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5639, 5641, 8855, 8858]
# Term: david
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5642, 5644, 8849, 8851]
# Term: filo
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5643, 5645, 8850, 8852]
# Term: 21
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5669, 10414, 10542, 10622, 10682, 10992, 12027, 13804]
# Term: 22
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5676, 9853, 9860, 9965, 11433, 11729, 12314, 12470, 12658, 12925, 13142, 13239, 14056, 14174, 14372, 14456, 14536]
# Term: way
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5682, 7944, 8307, 8622, 8649, 8888, 8998, 9292, 9369, 11717]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2180, 2365, 3279]
# Term: peopl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5683, 7008, 7740, 8130]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [846, 864, 2002]
# Term: interest
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5687, 5862]
# Term: oper
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5690, 6694, 6760, 6764, 6775, 11723]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2104]
# Term: rather
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5693, 7506, 8862, 8944]
# Term: copi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5694]
# Term: soon
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5698, 8620]
# Term: number
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5699, 6063, 6401, 7721, 8056, 8169, 8877, 9427, 11077, 15828]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [320]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3894]
# Term: vie
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5703]
# Term: seeker
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5728, 6129, 6131]
# Term: robin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5737, 5739, 6080, 6082]
# Term: develop
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5741, 8470, 8552, 8798, 8975, 9622, 9625, 16227]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1988, 3410]
# Term: rank
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5750, 6059, 6858, 6860, 6944, 7391, 8036, 8039, 8047, 8153, 8166, 8175, 9393, 9413, 11222]
# Term: 23
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5755, 10325, 10615, 11613]
# Term: 24
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5762, 14497]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1754, 1867]
# Term: 25
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5769, 6099, 11355, 13393]
# Term: receiv
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5772, 5972, 7884, 8882]
# Term: patent
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5774, 5802, 5823, 6077, 6087, 10675, 11076, 11226]
# Term: 26
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5779, 11776, 11826, 12134]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1453, 1483, 1543, 1570, 1694]
# Term: qualiti
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5789, 8127, 14488]
# Term: 27
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5796]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2354]
# Term: later
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5808, 5832, 6046, 8372, 8498]
# Term: 28
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5813, 10965, 10973]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1535]
# Term: larri
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5816, 5818, 6042, 6044, 6075, 10082]
# Term: 29
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5828, 6092, 6228, 10048, 10131, 10302, 10316, 10694, 10750, 12703, 12966, 13447, 16248]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2142, 3442]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4143]
# Term: china
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5841, 7220, 7267, 7281, 12386]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [600]
# Term: netscap
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5846, 5847, 5858, 5864, 5878, 11277, 11338]
# Term: look
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5848, 6785, 9032, 11872]
# Term: exclus
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5853, 15219, 15222]
# Term: deal
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5854, 5866, 6233, 8187, 11281, 11336]
# Term: much
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5861, 6923, 8524, 8953]
# Term: struck
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5865]
# Term: five
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5867, 5882]
# Term: million
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5872, 6841, 7377, 7885, 8813]
# Term: rotat
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5877]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2214]
# Term: 30
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5892, 11709, 14702]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1384, 1386, 1750, 1835, 2143, 3025]
# Term: 31
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5899, 11483, 16259]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2144, 3453]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4154]
# Term: adopt
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5905]
# Term: idea
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5906, 8741]
# Term: sell
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5907]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2039]
# Term: term
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5909, 6552, 6782, 7607, 14405, 16179, 16189, 16191]
# Term: signific
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5920]
# Term: effect
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5921, 8954, 9561, 9563, 9598, 9602]
# Term: struggl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5926]
# Term: profit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5928]
# Term: nowrap
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5932, 7309, 9750, 9801, 9859, 9908, 9971, 10034, 10117, 10301, 10352, 10400, 10506, 10565, 10621, 10681, 10806, 10855, 10979, 11120, 11172, 11239, 11298, 11397, 11482, 11527, 11612, 11728, 11775, 11825, 11922, 11979, 12033, 12083, 12133, 12265, 12422, 12605, 12878, 13094, 13205, 13295, 13344, 13407, 13469, 13532, 13607, 13679, 13745, 13818, 13937, 14018, 14115, 14337, 14421, 14500, 14589, 14885, 14951]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2493]
# Term: claim
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5938]
# Term: reliabl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5941]
# Term: brightest
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5953]
# Term: star
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5954]
# Term: invest
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5956, 7859]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2020]
# Term: frenzi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5957]
# Term: occur
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5958, 8611]
# Term: 32
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5964, 13862]
# Term: sever
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5967, 7531, 8096]
# Term: enter
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5969, 6601, 6789, 8908, 9041]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2417]
# Term: spectacularli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5971]
# Term: record
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5973, 8012]
# Term: gain
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5974]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [327]
# Term: offer
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5977, 5980, 6689]
# Term: taken
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5981]
# Term: caught
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5993]
# Term: boom
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5997]
# Term: peak
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [5998]
# Term: around
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6007, 8531]
# Term: rose
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6014]
# Term: 33
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6019, 14747]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1880, 1881, 2347]
# Term: achiev
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6023]
# Term: better
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6024, 8889, 14326]
# Term: explain
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6032, 9256]
# Term: paper
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6033]
# Term: anatomi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6034, 10088]
# Term: written
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6037]
# Term: sergey
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6038, 6040, 10080]
# Term: brin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6039, 6041, 10079]
# Term: founder
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6047]
# Term: iter
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6055, 6057]
# Term: premis
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6069]
# Term: good
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6070, 8626]
# Term: desir
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6071, 6739]
# Term: other
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6074, 6445, 6853, 7849, 8371]
# Term: earlier
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6084]
# Term: minimalist
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6105]
# Term: contrast
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6109]
# Term: competitor
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6111]
# Term: embed
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6112]
# Term: fact
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6119, 9266]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [349]
# Term: spoof
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6125]
# Term: emerg
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6127, 7680]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [359]
# Term: mysteri
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6128, 6130]
# Term: 2002
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6146, 12376]
# Term: nativ
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6148]
# Term: overtur
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6149]
# Term: own
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6150]
# Term: switch
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6155]
# Term: acquisit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6166]
# Term: fall
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6174]
# Term: earli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6180, 8599]
# Term: began
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6183, 6203, 8881]
# Term: looksmart
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6186, 6187]
# Term: blend
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6188]
# Term: time
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6192, 6307, 6407, 6754, 6889, 6973, 7967, 8157, 8597, 8617, 8768, 11342, 12702, 15779, 15789, 15793, 15821, 15834]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [321, 2136]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3853, 3863, 3867, 3900]
# Term: transit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6204]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2257, 2709]
# Term: power
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6207, 6239, 9153, 9161, 11869, 16256]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [355, 3450]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4151]
# Term: msnbot
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6213, 6214]
# Term: final
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6232]
# Term: anchor
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6283]
# Term: follow
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6303, 8352, 9187]
# Term: process
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6304, 6512, 6631, 6672, 6995, 7435, 7449, 7480, 7932, 8927, 9038, 9463, 9476, 11690, 12258, 13889]
# Term: near
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6305]
# Term: real
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6306, 6430, 6630, 11678, 11680, 11682, 13852, 13877, 13879, 13881, 15792]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3866]
# Term: 34
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6312, 7173]
# Term: ol
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6315, 9013, 9537, 9659, 9665, 14686, 14690, 14769, 14777, 14782, 14785, 14787, 14788, 14789, 14794, 14852, 14854, 14857, 14863, 14866, 14869, 14901, 14905]
# Term: 35
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6335, 6497, 6557, 6652, 6810, 6883]
# Term: spider
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6350, 6359, 6368, 6410, 6426, 6519, 8109, 9160, 9310, 15213, 15215]
# Term: check
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6351, 6365, 9209]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2735, 2756]
# Term: filenam
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6353]
# Term: direct
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6357, 7431]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2576, 2817]
# Term: tell
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6360]
# Term: either
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6366, 7817, 7962]
# Term: send
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6369]
# Term: certain
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6370, 6400, 7466, 7547]
# Term: factor
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6379, 8044]
# Term: javascript
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6383, 6384]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [396, 2497, 3331]
# Term: cascad
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6385, 6388]
# Term: sheet
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6387, 6390]
# Term: css
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6391]
# Term: spent
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6408]
# Term: stop
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6411]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1556, 1559, 1589, 1592, 1594, 1596, 1608, 1611, 1613, 1615, 1633, 1636, 1638, 1640, 1653, 1656, 1658, 1660, 1673, 1676, 1678, 1680, 1682]
# Term: actual
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6418, 6574, 9180, 9239, 9245]
# Term: reachabl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6421]
# Term: due
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6423, 7128, 9471]
# Term: infinit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6424]
# Term: trap
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6427, 15214, 15216]
# Term: spam
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6428]
# Term: exig
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6429]
# Term: appli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6434, 16181]
# Term: polici
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6436, 12976, 16198, 16200, 16213]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2064, 2086, 2117, 3397]
# Term: determin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6437, 7009, 8045, 8125, 9214, 9326, 9378]
# Term: deem
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6440]
# Term: suffici
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6441]
# Term: exhaust
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6444]
# Term: partial
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6447, 8598, 9018]
# Term: 36
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6452, 11693, 13892]
# Term: mean
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6457, 8126]
# Term: associ
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6458, 6470]
# Term: defin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6460, 6804]
# Term: token
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6461]
# Term: domain
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6465]
# Term: field
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6469]
# Term: multipl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6483, 8023]
# Term: quickli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6492, 6534]
# Term: techniqu
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6500, 6894]
# Term: cach
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6504, 6505, 6521, 6523, 6560, 6569, 15778, 15781, 15863]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3852, 3855, 3908]
# Term: trade
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6506]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2040]
# Term: secret
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6507]
# Term: wherea
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6508]
# Term: straightforward
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6511]
# Term: systemat
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6515]
# Term: render
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6528, 15872]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3917]
# Term: memori
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6533, 15825]
# Term: sent
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6535]
# Term: inquir
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6536]
# Term: overdu
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6538]
# Term: act
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6541]
# Term: proxi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6543, 6545]
# Term: case
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6547, 7089, 9233, 11593]
# Term: hold
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6562]
# Term: whose
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6565]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2073]
# Term: previous
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6567, 7279]
# Term: lost
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6576]
# Term: problem
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6577, 7675, 7683, 8676]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2171, 3283]
# Term: consid
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6579, 8873, 8918, 9350, 9389]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [313]
# Term: mild
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6580]
# Term: linkrot
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6582, 6583]
# Term: 168
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6589]
# Term: 500
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6591]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2549, 2706]
# Term: 382
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6592]
# Term: typic
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6599, 9349]
# Term: 37
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6616]
# Term: invert
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6619, 6913, 6915]
# Term: alreadi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6622]
# Term: instantli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6627]
# Term: everi
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6639, 6972, 9315]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [378, 381]
# Term: must
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6643, 8683]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2822]
# Term: weight
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6644, 6645, 6710, 6750]
# Term: accord
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6646, 7659]
# Term: lookup
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6660, 6686]
# Term: reconstruct
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6661]
# Term: markup
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6662]
# Term: snippet
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6664, 6666]
# Term: show
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6667, 6729, 7653]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2554]
# Term: context
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6668, 16329]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4198]
# Term: match
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6670, 6871, 8430]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [3293]
# Term: next
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6679, 10291]
# Term: beyond
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6683]
# Term: graphic
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6690]
# Term: gui
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6693]
# Term: paramet
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6696]
# Term: refin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6697, 6711, 6768, 6780]
# Term: necessari
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6701, 7948, 7975]
# Term: control
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6702, 15712, 15714]
# Term: engag
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6704]
# Term: feedback
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6705]
# Term: loop
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6706, 10599]
# Term: given
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6714]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [369]
# Term: exampl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6720, 7463, 7521, 9054, 9501]
# Term: click
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6728, 6975, 7646]
# Term: leftmost
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6732]
# Term: column
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6733]
# Term: 38
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6745, 14240]
# Term: possibl
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6749, 12255]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2155]
# Term: modif
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6753]
# Term: support
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6757, 6934, 10248]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [209, 399, 420, 2013, 2363, 2415, 3274]
# Term: boolean
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6759, 6763, 6774]
# Term: end
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6766, 14400]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [3104]
# Term: liter
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6776]
# Term: extend
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6781]
# Term: phrase
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6787, 6825, 6847]
# Term: exactli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6788, 9308]
# Term: advanc
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6793]
# Term: proxim
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6797, 6800]
# Term: distanc
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6805]
# Term: concept
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6814]
# Term: involv
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6818]
# Term: statist
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6820, 8743, 11916, 16230]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [3413]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4092]
# Term: set
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6837, 8321, 8354, 8364]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [3465]
# Term: authorit
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6852]
# Term: employ
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6856, 9423]
# Term: method
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6857, 6886, 8291, 8664, 11074, 11220]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2610, 2917]
# Term: order
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6859, 6872, 6906, 8367, 8747, 8892, 9410, 9467]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [400]
# Term: best
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6863, 6870, 9499]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [2364]
# Term: decid
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6868, 8315]
# Term: shown
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6874]
# Term: vari
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6875]
# Term: usag
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6891, 14217, 15790, 15794, 15822, 15826]
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3864, 3868]
# Term: evolv
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6895, 6901, 9425]
# Term: predefin
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6904]
# Term: hierarch
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6905]
# Term: human
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6908, 8116, 9162, 9222, 9312, 13200]
# Term: analyz
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6917, 9368, 9374, 12728]
# Term: reli
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6922, 9221]
# Term: heavili
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6924]
# Term: bulk
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6926]
# Term: ventur
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6933, 7891]
# Term: advertis
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6935, 6936, 6940, 6959, 7437]
# Term: revenu
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6937]
# Term: paid
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6941]
# Term: inclus
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6942]
# Term: higher
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6945, 9347]
# Term: fee
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6948]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1970]
# Term: accept
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6951]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1430, 2436]
# Term: money
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6952, 6956, 6971]
# Term: make
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6955, 6970, 7002, 8317, 8368, 9510]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [8, 215, 281, 2017, 2358, 2372]
# Term: run
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6957, 8670, 9479]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1995]
# Term: contextu
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6958]
# Term: alongsid
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6963]
# Term: regular
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6964, 8424, 8445]
# Term: someon
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6974, 8327]
# Term: 39
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6981, 7332, 12857, 15843, 16298]
# Term: effort
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [6997]
# Term: focu
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7000]
#   Document: https://donate.wikimedia.org/?wmf_source=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;uselang=en, Positions: [1415, 2258, 2740, 2741, 2753, 2757, 2865, 2868]
# Term: sure
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7003]
# Term: consist
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7005]
# Term: plan
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7010]
# Term: buy
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7012]
# Term: 160
#   Document: https://en.wikipedia.org/wiki/Web_search_engine, Positions: [7027, 10219, 10910, 10916, 11413, 11600, 11606, 12271, 12293, 12428, 12449, 12534, 12599, 12603, 12629, 12636, 12798, 12809, 12816, 12895, 12904, 13008, 13017, 13111, 13120, 13219, 13595, 13601, 13733, 13739, 13925, 13931, 14035, 14143, 14153, 14227, 14311, 14485, 14515, 16164]
# Term: far
# ...
# Term: пышӏагъэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3357]
# Term: нэкӏубгъорхэмэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3358]
# Term: яаужрэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3359]
# Term: зэблэхъухэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3360]
# Term: ехьылӏэгъэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3364]
# Term: зэблэхъуныгъэхэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3365]
# Term: uploadwizard
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3367]
# Term: файлэхэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3368]
# Term: къилъхь
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3369]
# Term: файлыр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3373]
# Term: илъхь
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3374]
# Term: шъхьаф
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3377]
# Term: яӏамышӏыкӏ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3383]
# Term: нэкӏубгъохэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3384]
# Term: къакiорэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3422]
# Term: зэмыхъокӏ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3423]
# Term: зэпыщ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3424, 3428, 3754]
# Term: ренэу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3426]
# Term: щыт
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3427]
# Term: информацие
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3469, 3513]
# Term: сайтыр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3509]
# Term: цитэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3510, 3517]
# Term: зэрэпшiыщтым
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3511]
# Term: фэгъэхьыгъэу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3512, 4032]
# Term: нэкiубгъор
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3516]
# Term: шiын
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3518]
# Term: 25d0
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3526, 3528, 3532, 3536, 3538, 3541, 3553, 3570, 3572, 3576, 3580, 3582, 3585, 3597]
# Term: 2598
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3527, 3571]
# Term: 25bd
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3529, 3537, 3573, 3581]
# Term: 25d1
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3530, 3534, 3540, 3543, 3545, 3547, 3549, 3551, 3555, 3557, 3574, 3578, 3584, 3587, 3589, 3591, 3593, 3595, 3599, 3601]
# Term: 2582
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3531, 3575]
# Term: 25b5
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3533, 3539, 3577, 3583]
# Term: 2580
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3535, 3579]
# Term: 25bb
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3542, 3554, 3586, 3598]
# Term: 258a
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3544, 3550, 3556, 3588, 3594, 3600]
# Term: 258b
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3546, 3590]
# Term: 2585
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3548, 3592]
# Term: 2583
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3552, 3596]
# Term: 258d
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3558, 3602]
# Term: тхылъ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3649]
# Term: фэдэу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3690]
# Term: къыхэщ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3691]
# Term: ихэутын
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3728]
# Term: теплъ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3729, 3734]
# Term: хэутын
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3733]
# Term: нэмыкӏ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3737]
# Term: проектхэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3738]
# Term: ехьылӏагъэу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3749]
# Term: хъарзынэщым
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3750]
# Term: элементгорэм
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3752]
# Term: гъэзэгъэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3753]
# Term: зыгор
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3759]
# Term: щыщ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3786]
# Term: ащыщых
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3796]
# Term: гугл
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3799, 3811]
# Term: яндекс
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3816, 3829]
# Term: яху
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3832, 3842]
# Term: нэмыкiхэри
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3847]
# Term: 20250105223759
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3854, 3914, 4193]
# Term: adywiki
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3910]
# Term: unknown
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3919]
# Term: м
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3941]
# Term: къикӏыгъ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3942]
# Term: мыщпэм
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3952]
# Term: зеӏэзагъэхэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3955]
# Term: текстыр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3960]
# Term: плъэгъушъущт
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3961]
# Term: мыщкӏэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3962]
# Term: лицензиер
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3967]
# Term: зиер
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3968]
# Term: ащ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3972]
# Term: нэмыкӏэу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3973]
# Term: зыгорэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3974]
# Term: ищыкӏэгъэнкӏи
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3975]
# Term: мэхъу
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3976]
# Term: гъэфедэныр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3981]
# Term: зытетыр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3982]
# Term: зыушъэфын
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3986]
# Term: хабзэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [3987]
# Term: пшъэдэкӏ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4081]
# Term: умыхьын
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4082]
# Term: програмшӏакӏохэр
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4089]
# Term: мобил
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4134]
# Term: теплъэ
#   Document: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D, Positions: [4135]
#
# --- Search Options ---
# 1. Search for a single word (TF-IDF based).
# 2. Search for a phrase (using Positional Inverted Index).
# Enter your choice (1/2): 2
# Enter the phrase to search: web search
#
# --- Phrase Search Results (Positional Index) ---
# 1. https://en.wikipedia.org/wiki/Web_search_engine
# 2. https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82-%D0%BB%D1%8A%D1%8B%D1%85%D1%8A%D1%83%D0%BB%D1%8A%D1%8D
